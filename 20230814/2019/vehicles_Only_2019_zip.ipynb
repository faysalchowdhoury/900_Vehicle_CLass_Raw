# %%
import pandas as pd

df=pd.read_excel('filtered_data_los angles _zip.xlsx')


# Convert 'Model Year' column to integer (if it is stored as a string)
df['Model Year'] = pd.to_numeric(df['Model Year'], errors='coerce')

# Filter the dataset to only include Model Year 2018
df_2018 = df.query("`Model Year` == 2019")

# Group the filtered dataset by 'Make' and 'Fuel' columns and calculate the sum of 'Vehicles' in each group
vehicles_by_Fuel_Duty = df_2018.groupby(['Make', 'Fuel'])['Vehicles'].sum().sort_values(ascending=False)

# Print the results
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(vehicles_by_Fuel_Duty)

# Calculate the total number of vehicles in the filtered DataFrame for Model Year 2018
total_vehicles_2019 = df_2019['Vehicles'].sum()
print("Total number of vehicles in 2019:", total_vehicles_2019)
# Out:
# Make               Fuel
# TOYOTA             Gasoline                    62712
# HONDA              Gasoline                    59046
# NISSAN             Gasoline                    24043
# OTHER/UNK          Gasoline                    23965
# CHEVROLET          Gasoline                    23070
# FORD               Gasoline                    21914
# MERCEDES-BENZ      Gasoline                    20697
# BMW                Gasoline                    15877
# SUBARU             Gasoline                    15526
# LEXUS              Gasoline                    15205
# VOLKSWAGEN         Gasoline                    13643
# KIA                Gasoline                    13445
# JEEP               Gasoline                    12017
# AUDI               Gasoline                    10748
# HYUNDAI            Gasoline                    10708
# TESLA              Battery Electric            10061
# MAZDA              Gasoline                     8597
# TOYOTA             Hybrid Gasoline              7776
# DODGE              Gasoline                     7172
# OTHER/UNK          Diesel and Diesel Hybrid     7022
#                    Plug-in Hybrid               6763
# INFINITI           Gasoline                     5297
# OTHER/UNK          Hybrid Gasoline              5109
# RAM                Gasoline                     4762
# OTHER/UNK          Flex-Fuel                    4689
#                    Battery Electric             4394
# ACURA              Gasoline                     3982
# LEXUS              Hybrid Gasoline              3334
# CADILLAC           Gasoline                     2827
# GMC                Gasoline                     2796
# LAND ROVER         Gasoline                     2783
# FORD               Flex-Fuel                    2729
# HONDA              Hybrid Gasoline              2344
# PORSCHE            Gasoline                     2252
# VOLVO              Gasoline                     2180
# MINI               Gasoline                     2175
# BMW                Plug-in Hybrid               1381
# FORD               Hybrid Gasoline              1367
# FREIGHTLINER       Diesel and Diesel Hybrid     1202
# KIA                Hybrid Gasoline              1091
# DODGE              Flex-Fuel                     946
# TOYOTA             Plug-in Hybrid                898
# FORD               Diesel and Diesel Hybrid      884
# CHEVROLET          Battery Electric              846
# ALFA ROMEO         Gasoline                      784
# HONDA              Plug-in Hybrid                715
# CHEVROLET          Flex-Fuel                     650
# OTHER/UNK          Hydrogen Fuel Cell            570
# LINCOLN            Gasoline                      487
# MITSUBISHI         Gasoline                      442
# AUDI               Battery Electric              420
# BUICK              Gasoline                      395
# INTERNATIONAL      Diesel and Diesel Hybrid      386
# KENWORTH           Diesel and Diesel Hybrid      342
# MERCEDES-BENZ      Diesel and Diesel Hybrid      325
# EL DORADO          Natural Gas                   291
# RAM                Diesel and Diesel Hybrid      255
# IC BUS             Other                         190
# ISUZU              Diesel and Diesel Hybrid      187
# OTHER/UNK          Natural Gas                   175
# VOLVO              Diesel and Diesel Hybrid      156
# MERCEDES-BENZ      Plug-in Hybrid                148
# OTHER/UNK          Unk                           141
# PETERBILT          Diesel and Diesel Hybrid      138
# JAGUAR             Gasoline                      137
# HINO               Diesel and Diesel Hybrid      136
# FREIGHTLINER       Gasoline                      133
# Unk                Unk                           117
# BMW                Battery Electric              100
# CHRYSLER           Gasoline                       99
# KENWORTH           Natural Gas                    82
# RAM                Flex-Fuel                      80
# FORD               Plug-in Hybrid                 69
# MASERATI           Gasoline                       69
# NEW FLYER          Natural Gas                    65
# HYUNDAI            Hybrid Gasoline                62
# NISSAN             Battery Electric               56
# AUTOCAR            Natural Gas                    56
# CHEVROLET          Diesel and Diesel Hybrid       47
# FREIGHTLINER       Other                          40
# PORSCHE            Plug-in Hybrid                 36
# GMC                Flex-Fuel                      36
# TOYOTA             Hydrogen Fuel Cell             29
# PETERBILT          Natural Gas                    28
# ROLLS-ROYCE        Gasoline                       24
# VOLKSWAGEN         Battery Electric               24
# CHRYSLER           Plug-in Hybrid                 23
# GREENPOWER MOTOR   Battery Electric               22
# CRANE CARRIER      Diesel and Diesel Hybrid       21
# BLUE BIRD          Diesel and Diesel Hybrid       20
# NEW FLYER          Battery Electric               20
# PIERCE             Diesel and Diesel Hybrid       20
# HYUNDAI            Plug-in Hybrid                 17
# KALMAR             Diesel and Diesel Hybrid       17
# ARBOC              Natural Gas                    14
# BENTLEY            Gasoline                       13
# FERRARI            Gasoline                       13
# BYD COACH AND BUS  Battery Electric               12
# CHEVROLET          Plug-in Hybrid                 12
# JEEP               Flex-Fuel                      12
# KOVATCH            Diesel and Diesel Hybrid       11
# OTHER/UNK          Other                          10
# Name: Vehicles, dtype: int64
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 20
#      17     print(vehicles_by_Fuel_Duty)
#      19 # Calculate the total number of vehicles in the filtered DataFrame for Model Year 2018
# ---> 20 total_vehicles_2019 = df_2019['Vehicles'].sum()
#      21 print("Total number of vehicles in 2019:", total_vehicles_2019)
#
# NameError: name 'df_2019' is not defined

# %%
# Convert the Series to a DataFrame
vehicles_by_Fuel_Duty_df = vehicles_by_Fuel_Duty.reset_index()

# Save the results as an Excel file
vehicles_by_Fuel_Duty_df.to_excel('vehicles_by_make_fuel_2019_zip.xlsx', index=False)

# Save the results as an CSV file
#vehicles_by_Fuel_Duty_df.to_csv('vehicles_by_make_fuel_2018_zip.csv', index=False)
