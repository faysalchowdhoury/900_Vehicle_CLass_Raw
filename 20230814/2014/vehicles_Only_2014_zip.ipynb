# %%
import pandas as pd

df=pd.read_excel('filtered_data_los angles _zip.xlsx')


# Convert 'Model Year' column to integer (if it is stored as a string)
df['Model Year'] = pd.to_numeric(df['Model Year'], errors='coerce')

# Filter the dataset to only include Model Year 2018
df_2014 = df.query("`Model Year` == 2014")

# Group the filtered dataset by 'Make' and 'Fuel' columns and calculate the sum of 'Vehicles' in each group
vehicles_by_Fuel_Duty = df_2014.groupby(['Make', 'Fuel'])['Vehicles'].sum().sort_values(ascending=False)

# Print the results
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(vehicles_by_Fuel_Duty)

# Calculate the total number of vehicles in the filtered DataFrame for Model Year 2018
total_vehicles_2014 = df_2014['Vehicles'].sum()
print("Total number of vehicles in 2014:", total_vehicles_2014)
# Out:
# Make                            Fuel
# TOYOTA                          Gasoline                    46923
# HONDA                           Gasoline                    38883
# NISSAN                          Gasoline                    26528
# OTHER/UNK                       Gasoline                    23988
# FORD                            Gasoline                    15886
# TOYOTA                          Hybrid Gasoline             13679
# MERCEDES-BENZ                   Gasoline                    12918
# CHEVROLET                       Gasoline                    12722
# BMW                             Gasoline                    11277
# KIA                             Gasoline                     9685
# JEEP                            Gasoline                     8678
# HYUNDAI                         Gasoline                     8112
# OTHER/UNK                       Diesel and Diesel Hybrid     7864
# LEXUS                           Gasoline                     7666
# OTHER/UNK                       Flex-Fuel                    6098
# MAZDA                           Gasoline                     6073
# VOLKSWAGEN                      Gasoline                     5998
# FORD                            Flex-Fuel                    5762
# SUBARU                          Gasoline                     4866
# OTHER/UNK                       Hybrid Gasoline              4561
# CHEVROLET                       Flex-Fuel                    4484
# DODGE                           Gasoline                     4245
# OTHER/UNK                       Plug-in Hybrid               3562
# AUDI                            Gasoline                     3239
# ACURA                           Gasoline                     2882
# SCION                           Gasoline                     2725
# FREIGHTLINER                    Diesel and Diesel Hybrid     2707
# OTHER/UNK                       Battery Electric             1856
# GMC                             Gasoline                     1790
# INFINITI                        Gasoline                     1752
# RAM                             Gasoline                     1551
# LEXUS                           Hybrid Gasoline              1211
# TOYOTA                          Plug-in Hybrid               1209
# PORSCHE                         Gasoline                      908
# MINI                            Gasoline                      872
# CADILLAC                        Gasoline                      747
# TESLA                           Battery Electric              544
# LAND ROVER                      Gasoline                      513
# CHEVROLET                       Plug-in Hybrid                476
# CHRYSLER                        Gasoline                      391
# OTHER/UNK                       Natural Gas                   385
# MITSUBISHI                      Gasoline                      375
# BUICK                           Gasoline                      324
# DODGE                           Flex-Fuel                     276
# PETERBILT                       Diesel and Diesel Hybrid      263
# Unk                             Unk                           235
# FORD                            Hybrid Gasoline               235
# INTERNATIONAL                   Diesel and Diesel Hybrid      219
# OTHER/UNK                       Unk                           173
# RAM                             Diesel and Diesel Hybrid      158
# HINO                            Diesel and Diesel Hybrid      109
# KENWORTH                        Diesel and Diesel Hybrid      102
# ISUZU                           Diesel and Diesel Hybrid      102
# FORD                            Plug-in Hybrid                 92
# FIAT                            Gasoline                       72
# HONDA                           Hybrid Gasoline                72
# NORTH AMERICAN                  Natural Gas                    59
# AM GENERAL                      Natural Gas                    58
# FORD                            Diesel and Diesel Hybrid       54
# THOMAS BUS                      Natural Gas                    53
# MACK                            Diesel and Diesel Hybrid       44
# VOLKSWAGEN                      Diesel and Diesel Hybrid       44
# HONDA                           Natural Gas                    35
# EL DORADO                       Natural Gas                    31
# CHRYSLER                        Flex-Fuel                      28
# GMC                             Flex-Fuel                      26
# GILLIG                          Diesel and Diesel Hybrid       24
# PETERBILT                       Natural Gas                    23
# OTHER/UNK                       Other                          21
# PREVOST                         Diesel and Diesel Hybrid       20
# KENWORTH                        Natural Gas                    16
# FREIGHTLINER                    Natural Gas                    15
# NEW FLYER                       Natural Gas                    13
# BLUE BIRD                       Other                          13
# BENTLEY                         Gasoline                       13
# VOLVO                           Diesel and Diesel Hybrid       13
# LINCOLN                         Gasoline                       12
# KIA                             Hybrid Gasoline                12
# KOVATCH MOBLIE EQUIPMENT CORP.  Diesel and Diesel Hybrid       11
# ALEXANDER DENNIS                Diesel and Diesel Hybrid       11
# INFINITI                        Hybrid Gasoline                11
# Name: Vehicles, dtype: int64
# Total number of vehicles in 2014: 319683

# %%
# Convert the Series to a DataFrame
vehicles_by_Fuel_Duty_df = vehicles_by_Fuel_Duty.reset_index()

# Save the results as an Excel file
vehicles_by_Fuel_Duty_df.to_excel('vehicles_by_make_fuel_2014_zip.xlsx', index=False)

# Save the results as an CSV file
#vehicles_by_Fuel_Duty_df.to_csv('vehicles_by_make_fuel_2018_zip.csv', index=False)
