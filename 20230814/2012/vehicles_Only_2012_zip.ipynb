# %%
import pandas as pd

df=pd.read_excel('filtered_data_los angles _zip.xlsx')


# Convert 'Model Year' column to integer (if it is stored as a string)
df['Model Year'] = pd.to_numeric(df['Model Year'], errors='coerce')

# Filter the dataset to only include Model Year 2018
df_2012 = df.query("`Model Year` == 2012")

# Group the filtered dataset by 'Make' and 'Fuel' columns and calculate the sum of 'Vehicles' in each group
vehicles_by_Fuel_Duty = df_2012.groupby(['Make', 'Fuel'])['Vehicles'].sum().sort_values(ascending=False)

# Print the results
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(vehicles_by_Fuel_Duty)

# Calculate the total number of vehicles in the filtered DataFrame for Model Year 2018
total_vehicles_2012 = df_2012['Vehicles'].sum()
print("Total number of vehicles in 2012:", total_vehicles_2012)
# Out:
# Make                            Fuel
# HONDA                           Gasoline                    41121
# TOYOTA                          Gasoline                    38468
# OTHER/UNK                       Gasoline                    25072
# NISSAN                          Gasoline                    21042
# TOYOTA                          Hybrid Gasoline             14015
# FORD                            Gasoline                    11374
# CHEVROLET                       Gasoline                     8646
# HYUNDAI                         Gasoline                     8419
# OTHER/UNK                       Flex-Fuel                    7874
# VOLKSWAGEN                      Gasoline                     7745
# MERCEDES-BENZ                   Gasoline                     7552
# KIA                             Gasoline                     6859
# OTHER/UNK                       Diesel and Diesel Hybrid     6518
# BMW                             Gasoline                     5178
# JEEP                            Gasoline                     4342
# LEXUS                           Gasoline                     4167
# SCION                           Gasoline                     3775
# CHEVROLET                       Flex-Fuel                    3747
# MAZDA                           Gasoline                     3730
# OTHER/UNK                       Hybrid Gasoline              3529
# FORD                            Flex-Fuel                    2965
# ACURA                           Gasoline                     2585
# DODGE                           Gasoline                     2313
# AUDI                            Gasoline                     2024
# FREIGHTLINER                    Diesel and Diesel Hybrid     1838
# MINI                            Gasoline                     1693
# OTHER/UNK                       Plug-in Hybrid               1654
# SUBARU                          Gasoline                     1416
# FIAT                            Gasoline                     1379
# INFINITI                        Gasoline                     1197
# OTHER/UNK                       Battery Electric              754
# GMC                             Gasoline                      738
# LEXUS                           Hybrid Gasoline               719
# OTHER/UNK                       Natural Gas                   674
# GMC                             Flex-Fuel                     612
# VOLVO                           Gasoline                      532
# CHRYSLER                        Gasoline                      517
# TOYOTA                          Plug-in Hybrid                508
# RAM                             Gasoline                      448
# INTERNATIONAL                   Diesel and Diesel Hybrid      362
# LAND ROVER                      Gasoline                      306
# PORSCHE                         Gasoline                      297
# PETERBILT                       Diesel and Diesel Hybrid      291
# MITSUBISHI                      Gasoline                      214
# FORD                            Diesel and Diesel Hybrid      207
# DODGE                           Flex-Fuel                     198
# BUICK                           Gasoline                      172
# NORTH AMERICAN BUS INDUSTRIES   Natural Gas                   150
# CADILLAC                        Flex-Fuel                     139
# RAM                             Diesel and Diesel Hybrid      135
# OTHER/UNK                       Unk                           131
# MOTOR COACH INDUSTRIES          Diesel and Diesel Hybrid       94
# KENWORTH                        Diesel and Diesel Hybrid       86
# CADILLAC                        Gasoline                       76
# HONDA                           Natural Gas                    73
# Unk                             Unk                            71
# FREIGHTLINER                    Natural Gas                    65
# THOMAS BUS                      Natural Gas                    64
# GILLIG                          Diesel and Diesel Hybrid       59
# BLUE BIRD                       Natural Gas                    58
# HINO                            Diesel and Diesel Hybrid       57
# HONDA                           Hybrid Gasoline                57
# AUTOCAR                         Natural Gas                    54
# FORD                            Hybrid Gasoline                50
# PETERBILT                       Natural Gas                    45
# EL DORADO                       Natural Gas                    36
# VPG                             Natural Gas                    32
# NEW FLYER                       Natural Gas                    16
# VOLKSWAGEN                      Diesel and Diesel Hybrid       14
# KOVATCH MOBLIE EQUIPMENT CORP.  Diesel and Diesel Hybrid       14
# CRANE CARRIER                   Natural Gas                    12
# PREVOST                         Diesel and Diesel Hybrid       12
# Name: Vehicles, dtype: int64
# Total number of vehicles in 2012: 261386

# %%
# Convert the Series to a DataFrame
vehicles_by_Fuel_Duty_df = vehicles_by_Fuel_Duty.reset_index()

# Save the results as an Excel file
vehicles_by_Fuel_Duty_df.to_excel('vehicles_by_make_fuel_2012_zip.xlsx', index=False)

# Save the results as an CSV file
#vehicles_by_Fuel_Duty_df.to_csv('vehicles_by_make_fuel_2018_zip.csv', index=False)
