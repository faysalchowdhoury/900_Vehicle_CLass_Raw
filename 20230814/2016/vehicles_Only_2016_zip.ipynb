# %%
import pandas as pd

df=pd.read_excel('filtered_data_los angles _zip.xlsx')


# Convert 'Model Year' column to integer (if it is stored as a string)
df['Model Year'] = pd.to_numeric(df['Model Year'], errors='coerce')

# Filter the dataset to only include Model Year 2018
df_2016 = df.query("`Model Year` == 2016")

# Group the filtered dataset by 'Make' and 'Fuel' columns and calculate the sum of 'Vehicles' in each group
vehicles_by_Fuel_Duty = df_2016.groupby(['Make', 'Fuel'])['Vehicles'].sum().sort_values(ascending=False)

# Print the results
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(vehicles_by_Fuel_Duty)

# Calculate the total number of vehicles in the filtered DataFrame for Model Year 2018
total_vehicles_2016 = df_2016['Vehicles'].sum()
print("Total number of vehicles in 2016:", total_vehicles_2016)
# Out:
# Make                    Fuel
# HONDA                   Gasoline                    60994
# TOYOTA                  Gasoline                    53489
# NISSAN                  Gasoline                    29693
# OTHER/UNK               Gasoline                    25717
# FORD                    Gasoline                    20035
# CHEVROLET               Gasoline                    18732
# KIA                     Gasoline                    17431
# MAZDA                   Gasoline                    13209
# BMW                     Gasoline                    13101
# TOYOTA                  Hybrid Gasoline             13018
# LEXUS                   Gasoline                    12094
# MERCEDES-BENZ           Gasoline                    11785
# HYUNDAI                 Gasoline                    11778
# JEEP                    Gasoline                     9083
# OTHER/UNK               Diesel and Diesel Hybrid     8845
# SUBARU                  Gasoline                     8184
# VOLKSWAGEN              Gasoline                     7921
# OTHER/UNK               Flex-Fuel                    7480
# FORD                    Flex-Fuel                    5297
# AUDI                    Gasoline                     5079
# DODGE                   Gasoline                     5060
# ACURA                   Gasoline                     4045
# CHEVROLET               Flex-Fuel                    3940
# OTHER/UNK               Hybrid Gasoline              3762
# SCION                   Gasoline                     3740
# FREIGHTLINER            Diesel and Diesel Hybrid     3707
# OTHER/UNK               Plug-in Hybrid               3659
# GMC                     Gasoline                     2685
# OTHER/UNK               Battery Electric             2617
# TESLA                   Battery Electric             2571
# LEXUS                   Hybrid Gasoline              2267
# LAND ROVER              Gasoline                     1758
# CADILLAC                Gasoline                     1572
# PORSCHE                 Gasoline                     1570
# INFINITI                Gasoline                     1216
# RAM                     Gasoline                     1215
# MINI                    Gasoline                     1152
# CHRYSLER                Gasoline                      840
# BUICK                   Gasoline                      823
# VOLVO                   Gasoline                      780
# DODGE                   Flex-Fuel                     649
# RAM                     Diesel and Diesel Hybrid      461
# INTERNATIONAL           Diesel and Diesel Hybrid      455
# KENWORTH                Diesel and Diesel Hybrid      423
# FORD                    Plug-in Hybrid                401
#                         Diesel and Diesel Hybrid      397
# PETERBILT               Diesel and Diesel Hybrid      388
# HINO                    Diesel and Diesel Hybrid      327
# MITSUBISHI              Gasoline                      294
# OTHER/UNK               Natural Gas                   257
# VOLVO                   Diesel and Diesel Hybrid      255
# ISUZU                   Diesel and Diesel Hybrid      221
# GMC                     Flex-Fuel                     217
# OTHER/UNK               Unk                           206
#                         Hydrogen Fuel Cell            155
# FORD                    Hybrid Gasoline               143
# Unk                     Unk                           129
# JEEP                    Flex-Fuel                     110
# BMW                     Plug-in Hybrid                102
# FREIGHTLINER            Gasoline                      101
# FIAT                    Gasoline                       85
# MERCEDES-BENZ           Diesel and Diesel Hybrid       62
# PETERBILT               Natural Gas                    58
# HYUNDAI                 Hybrid Gasoline                56
# AUDI                    Plug-in Hybrid                 54
# CHEVROLET               Plug-in Hybrid                 50
# LINCOLN                 Gasoline                       49
# NEW FLYER               Natural Gas                    48
# AUTOCAR                 Natural Gas                    47
# NISSAN                  Battery Electric               45
# AM GENERAL              Natural Gas                    45
# ISUZU                   Gasoline                       41
# VOLKSWAGEN              Battery Electric               40
# DODGE                   Diesel and Diesel Hybrid       28
# RAM                     Flex-Fuel                      26
# CHEVROLET               Diesel and Diesel Hybrid       26
# FREIGHTLINER            Other                          26
# KIA                     Hybrid Gasoline                25
# FREIGHTLINER            Natural Gas                    24
# KALMAR                  Diesel and Diesel Hybrid       23
# EL DORADO               Natural Gas                    20
# OTHER/UNK               Other                          20
# KIA                     Battery Electric               18
# BLUE BIRD               Gasoline                       13
# MOTOR COACH INDUSTRIES  Diesel and Diesel Hybrid       13
# LAND ROVER              Diesel and Diesel Hybrid       12
# Name: Vehicles, dtype: int64
# Total number of vehicles in 2016: 408589

# %%
# Convert the Series to a DataFrame
vehicles_by_Fuel_Duty_df = vehicles_by_Fuel_Duty.reset_index()

# Save the results as an Excel file
vehicles_by_Fuel_Duty_df.to_excel('vehicles_by_make_fuel_2016_zip.xlsx', index=False)

# Save the results as an CSV file
#vehicles_by_Fuel_Duty_df.to_csv('vehicles_by_make_fuel_2018_zip.csv', index=False)
