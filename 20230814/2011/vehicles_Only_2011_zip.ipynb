# %%
import pandas as pd

df=pd.read_excel('filtered_data_los angles _zip.xlsx')


# Convert 'Model Year' column to integer (if it is stored as a string)
df['Model Year'] = pd.to_numeric(df['Model Year'], errors='coerce')

# Filter the dataset to only include Model Year 2018
df_2011 = df.query("`Model Year` == 2011")

# Group the filtered dataset by 'Make' and 'Fuel' columns and calculate the sum of 'Vehicles' in each group
vehicles_by_Fuel_Duty = df_2011.groupby(['Make', 'Fuel'])['Vehicles'].sum().sort_values(ascending=False)

# Print the results
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(vehicles_by_Fuel_Duty)

# Calculate the total number of vehicles in the filtered DataFrame for Model Year 2018
total_vehicles_2011 = df_2011['Vehicles'].sum()
print("Total number of vehicles in 2011:", total_vehicles_2011)
# Out:
# Make                            Fuel
# TOYOTA                          Gasoline                    40862
# HONDA                           Gasoline                    24681
# OTHER/UNK                       Gasoline                    23960
# NISSAN                          Gasoline                    14408
# FORD                            Gasoline                    10871
# BMW                             Gasoline                     9880
# TOYOTA                          Hybrid Gasoline              8538
# MERCEDES-BENZ                   Gasoline                     7346
# HYUNDAI                         Gasoline                     6721
# OTHER/UNK                       Flex-Fuel                    6475
# CHEVROLET                       Gasoline                     6050
#                                 Flex-Fuel                    5739
# LEXUS                           Gasoline                     5517
# OTHER/UNK                       Diesel and Diesel Hybrid     5102
# KIA                             Gasoline                     4968
# FORD                            Flex-Fuel                    4494
# VOLKSWAGEN                      Gasoline                     3366
# OTHER/UNK                       Hybrid Gasoline              3159
# MAZDA                           Gasoline                     2881
# JEEP                            Gasoline                     2798
# INFINITI                        Gasoline                     1943
# SCION                           Gasoline                     1792
# SUBARU                          Gasoline                     1412
# DODGE                           Gasoline                     1254
# ACURA                           Gasoline                     1250
# AUDI                            Gasoline                     1168
# FREIGHTLINER                    Diesel and Diesel Hybrid      732
# MINI                            Gasoline                      650
# GMC                             Flex-Fuel                     626
# OTHER/UNK                       Battery Electric              512
#                                 Natural Gas                   451
# CADILLAC                        Gasoline                      404
# LAND ROVER                      Gasoline                      302
# GMC                             Gasoline                      296
# PORSCHE                         Gasoline                      294
# FORD                            Diesel and Diesel Hybrid      267
# LEXUS                           Hybrid Gasoline               222
# MITSUBISHI                      Gasoline                      204
# INTERNATIONAL                   Diesel and Diesel Hybrid      189
# HONDA                           Hybrid Gasoline               175
# AUTOCAR                         Natural Gas                   157
# OTHER/UNK                       Plug-in Hybrid                145
# BLUE BIRD                       Natural Gas                   126
# RAM                             Gasoline                      119
# BUICK                           Gasoline                      117
# VOLVO                           Gasoline                      106
# OTHER/UNK                       Unk                            99
# THOMAS BUS                      Natural Gas                    99
# PETERBILT                       Natural Gas                    64
#                                 Diesel and Diesel Hybrid       56
# Unk                             Unk                            56
# RAM                             Diesel and Diesel Hybrid       50
# KENWORTH                        Diesel and Diesel Hybrid       40
# CHRYSLER                        Gasoline                       39
# KOVATCH MOBLIE EQUIPMENT CORP.  Diesel and Diesel Hybrid       37
# FORD                            Hybrid Gasoline                33
# VOLVO                           Diesel and Diesel Hybrid       32
# NEW FLYER                       Natural Gas                    20
# NORTH AMERICAN                  Natural Gas                    14
# JAGUAR                          Gasoline                       13
# CADILLAC                        Flex-Fuel                      12
# ISUZU                           Diesel and Diesel Hybrid       12
# DODGE                           Flex-Fuel                      11
# Name: Vehicles, dtype: int64
# Total number of vehicles in 2011: 213416

# %%
# Convert the Series to a DataFrame
vehicles_by_Fuel_Duty_df = vehicles_by_Fuel_Duty.reset_index()

# Save the results as an Excel file
vehicles_by_Fuel_Duty_df.to_excel('vehicles_by_make_fuel_2011_zip.xlsx', index=False)

# Save the results as an CSV file
#vehicles_by_Fuel_Duty_df.to_csv('vehicles_by_make_fuel_2018_zip.csv', index=False)
