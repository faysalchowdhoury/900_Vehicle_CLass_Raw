# %%
import pandas as pd

df=pd.read_excel('filtered_data_los angles _zip.xlsx')


# Convert 'Model Year' column to integer (if it is stored as a string)
df['Model Year'] = pd.to_numeric(df['Model Year'], errors='coerce')

# Filter the dataset to only include Model Year 2018
df_2022 = df.query("`Model Year` == 2022")

# Group the filtered dataset by 'Make' and 'Fuel' columns and calculate the sum of 'Vehicles' in each group
vehicles_by_Fuel_Duty = df_2022.groupby(['Make', 'Fuel'])['Vehicles'].sum().sort_values(ascending=False)

# Print the results
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(vehicles_by_Fuel_Duty)

# Calculate the total number of vehicles in the filtered DataFrame for Model Year 2018
total_vehicles_2022 = df_2018['Vehicles'].sum()
print("Total number of vehicles in 2022:", total_vehicles_2022)
# Out:
# Make           Fuel
# TOYOTA         Gasoline                    53097
# TESLA          Battery Electric            45747
# HONDA          Gasoline                    38464
# OTHER/UNK      Gasoline                    20900
# KIA            Gasoline                    19686
# MERCEDES-BENZ  Gasoline                    19050
# CHEVROLET      Gasoline                    18586
# TOYOTA         Hybrid Gasoline             18218
# BMW            Gasoline                    17575
# FORD           Gasoline                    16262
# NISSAN         Gasoline                    16227
# SUBARU         Gasoline                    11608
# HYUNDAI        Gasoline                    10902
# LEXUS          Gasoline                    10592
# OTHER/UNK      Battery Electric             9938
# VOLKSWAGEN     Gasoline                     8281
# JEEP           Gasoline                     7513
# HONDA          Hybrid Gasoline              7302
# AUDI           Gasoline                     7288
# OTHER/UNK      Plug-in Hybrid               6715
#                Diesel and Diesel Hybrid     6312
# MAZDA          Gasoline                     5737
# LEXUS          Hybrid Gasoline              5202
# OTHER/UNK      Hybrid Gasoline              5010
# DODGE          Gasoline                     3996
# PORSCHE        Gasoline                     2748
# CHRYSLER       Gasoline                     2491
# ACURA          Gasoline                     2353
# GMC            Gasoline                     2336
# LAND ROVER     Gasoline                     2189
# TOYOTA         Plug-in Hybrid               1931
# RAM            Gasoline                     1876
# OTHER/UNK      Flex-Fuel                    1593
# HYUNDAI        Battery Electric             1162
# FORD           Battery Electric             1074
# BMW            Plug-in Hybrid               1071
# CADILLAC       Gasoline                     1067
# CHEVROLET      Battery Electric             1044
# FORD           Flex-Fuel                     938
# AUDI           Battery Electric              850
# KIA            Hybrid Gasoline               807
# VOLVO          Plug-in Hybrid                789
# KIA            Battery Electric              776
# MITSUBISHI     Gasoline                      748
# INFINITI       Gasoline                      728
# JEEP           Plug-in Hybrid                719
# OTHER/UNK      Hydrogen Fuel Cell            709
# BUICK          Gasoline                      694
# GENESIS        Gasoline                      635
# HYUNDAI        Hybrid Gasoline               589
# FORD           Hybrid Gasoline               588
# ALFA ROMEO     Gasoline                      585
# VOLVO          Gasoline                      579
# MINI           Gasoline                      566
# RAM            Diesel and Diesel Hybrid      555
# FREIGHTLINER   Diesel and Diesel Hybrid      515
# CHRYSLER       Plug-in Hybrid                478
# RAM            Flex-Fuel                     434
# CHEVROLET      Diesel and Diesel Hybrid      416
# MERCEDES-BENZ  Battery Electric              375
# INTERNATIONAL  Diesel and Diesel Hybrid      362
# PORSCHE        Battery Electric              338
# FORD           Diesel and Diesel Hybrid      269
# PETERBILT      Diesel and Diesel Hybrid      205
# LINCOLN        Gasoline                      186
# RIVIAN         Battery Electric              181
# GMC            Diesel and Diesel Hybrid      172
# OTHER/UNK      Natural Gas                   133
# KENWORTH       Diesel and Diesel Hybrid      130
# MERCEDES-BENZ  Diesel and Diesel Hybrid      128
# VOLVO          Diesel and Diesel Hybrid      123
# JAGUAR         Gasoline                      118
# AUTOCAR        Natural Gas                   116
# OTHER/UNK      Unk                           113
# POLESTAR       Battery Electric              112
# FREIGHTLINER   Gasoline                       89
# BMW            Battery Electric               82
# IC BUS         Gasoline                       78
# TOYOTA         Hydrogen Fuel Cell             75
# Unk            Unk                            68
# FREIGHTLINER   Natural Gas                    57
# MASERATI       Gasoline                       53
# AUDI           Plug-in Hybrid                 48
# ISUZU          Diesel and Diesel Hybrid       45
# BENTLEY        Gasoline                       44
# EL DORADO      Natural Gas                    41
# PETERBILT      Natural Gas                    37
# FERRARI        Gasoline                       28
# HYUNDAI        Plug-in Hybrid                 26
# VOLVO          Battery Electric               25
# MITSUBISHI     Plug-in Hybrid                 22
# VOLVO          Natural Gas                    20
# MACK           Diesel and Diesel Hybrid       20
# ROLLS-ROYCE    Gasoline                       19
# NEW FLYER      Hydrogen Fuel Cell             14
# KIA            Plug-in Hybrid                 13
# VOLKSWAGEN     Battery Electric               12
# ISUZU          Gasoline                       12
# OTHER/UNK      Other                           3
# Name: Vehicles, dtype: int64
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 20
#      17     print(vehicles_by_Fuel_Duty)
#      19 # Calculate the total number of vehicles in the filtered DataFrame for Model Year 2018
# ---> 20 total_vehicles_2022 = df_2018['Vehicles'].sum()
#      21 print("Total number of vehicles in 2022:", total_vehicles_2022)
#
# NameError: name 'df_2018' is not defined

# %%
# Convert the Series to a DataFrame
vehicles_by_Fuel_Duty_df = vehicles_by_Fuel_Duty.reset_index()

# Save the results as an Excel file
vehicles_by_Fuel_Duty_df.to_excel('vehicles_by_make_fuel_2022_zip.xlsx', index=False)

# Save the results as an CSV file
#vehicles_by_Fuel_Duty_df.to_csv('vehicles_by_make_fuel_2018_zip.csv', index=False)
