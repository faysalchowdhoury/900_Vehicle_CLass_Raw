# %%
import pandas as pd

df=pd.read_excel('filtered_data_los angles _zip.xlsx')


# Convert 'Model Year' column to integer (if it is stored as a string)
df['Model Year'] = pd.to_numeric(df['Model Year'], errors='coerce')

# Filter the dataset to only include Model Year 2018
df_2013 = df.query("`Model Year` == 2013")

# Group the filtered dataset by 'Make' and 'Fuel' columns and calculate the sum of 'Vehicles' in each group
vehicles_by_Fuel_Duty = df_2013.groupby(['Make', 'Fuel'])['Vehicles'].sum().sort_values(ascending=False)

# Print the results
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(vehicles_by_Fuel_Duty)

# Calculate the total number of vehicles in the filtered DataFrame for Model Year 2018
total_vehicles_2013 = df_2013['Vehicles'].sum()
print("Total number of vehicles in 2013:", total_vehicles_2013)
# Out:
# Make                            Fuel
# TOYOTA                          Gasoline                    43130
# HONDA                           Gasoline                    42772
# OTHER/UNK                       Gasoline                    24895
# NISSAN                          Gasoline                    22361
# TOYOTA                          Hybrid Gasoline             16614
# HYUNDAI                         Gasoline                    16452
# FORD                            Gasoline                    15865
# KIA                             Gasoline                    11929
# CHEVROLET                       Gasoline                    10376
# BMW                             Gasoline                    10278
# MERCEDES-BENZ                   Gasoline                     9596
# VOLKSWAGEN                      Gasoline                     8291
# LEXUS                           Gasoline                     8285
# OTHER/UNK                       Flex-Fuel                    6428
#                                 Diesel and Diesel Hybrid     6261
# FORD                            Flex-Fuel                    5485
# CHEVROLET                       Flex-Fuel                    4928
# DODGE                           Gasoline                     4918
# OTHER/UNK                       Hybrid Gasoline              4530
# SCION                           Gasoline                     3905
# MAZDA                           Gasoline                     3884
# SUBARU                          Gasoline                     3672
# AUDI                            Gasoline                     3193
# LEXUS                           Hybrid Gasoline              3118
# JEEP                            Gasoline                     2764
# OTHER/UNK                       Plug-in Hybrid               2741
# INFINITI                        Gasoline                     2705
# MINI                            Gasoline                     2581
# ACURA                           Gasoline                     2368
# OTHER/UNK                       Battery Electric             1905
# FREIGHTLINER                    Diesel and Diesel Hybrid     1805
# FORD                            Hybrid Gasoline               948
# PORSCHE                         Gasoline                      656
# CHEVROLET                       Plug-in Hybrid                639
# CHRYSLER                        Gasoline                      610
# TESLA                           Battery Electric              598
# FIAT                            Gasoline                      597
# NEW FLYER                       Natural Gas                   540
# INTERNATIONAL                   Diesel and Diesel Hybrid      431
# LAND ROVER                      Gasoline                      426
# CADILLAC                        Gasoline                      411
# RAM                             Gasoline                      386
# VOLVO                           Gasoline                      363
# GMC                             Gasoline                      296
# OTHER/UNK                       Natural Gas                   263
# PETERBILT                       Diesel and Diesel Hybrid      245
# GMC                             Flex-Fuel                     239
# BUICK                           Gasoline                      215
# HINO                            Diesel and Diesel Hybrid      164
# TOYOTA                          Plug-in Hybrid                161
# Unk                             Unk                           146
# OTHER/UNK                       Unk                           138
# KENWORTH                        Diesel and Diesel Hybrid      111
# PETERBILT                       Natural Gas                    84
# CADILLAC                        Flex-Fuel                      75
# FORD                            Plug-in Hybrid                 73
# NISSAN                          Battery Electric               73
# NORTH AMERICAN                  Natural Gas                    64
# VOLKSWAGEN                      Diesel and Diesel Hybrid       52
# HONDA                           Hybrid Gasoline                50
# GILLIG                          Diesel and Diesel Hybrid       44
# FREIGHTLINER                    Natural Gas                    41
# MACK                            Natural Gas                    39
# MITSUBISHI                      Gasoline                       38
# ISUZU                           Diesel and Diesel Hybrid       33
# FORD                            Diesel and Diesel Hybrid       28
# HYUNDAI                         Hybrid Gasoline                27
# MACK                            Diesel and Diesel Hybrid       25
# BLUE BIRD                       Other                          18
# MOTOR COACH INDUSTRIES          Diesel and Diesel Hybrid       16
# EL DORADO                       Natural Gas                    15
# RAM                             Flex-Fuel                      13
# MERCEDES-BENZ                   Diesel and Diesel Hybrid       13
# KOVATCH MOBLIE EQUIPMENT CORP.  Diesel and Diesel Hybrid       13
# CHRYSLER                        Flex-Fuel                      12
# LINCOLN                         Gasoline                       12
# BENTLEY                         Gasoline                       11
# Name: Vehicles, dtype: int64
# Total number of vehicles in 2013: 317487

# %%
# Convert the Series to a DataFrame
vehicles_by_Fuel_Duty_df = vehicles_by_Fuel_Duty.reset_index()

# Save the results as an Excel file
vehicles_by_Fuel_Duty_df.to_excel('vehicles_by_make_fuel_2013_zip.xlsx', index=False)

# Save the results as an CSV file
#vehicles_by_Fuel_Duty_df.to_csv('vehicles_by_make_fuel_2018_zip.csv', index=False)
