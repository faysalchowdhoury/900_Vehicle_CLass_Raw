# %%
import pandas as pd

df=pd.read_excel('filtered_data_los angles _zip.xlsx')


# Convert 'Model Year' column to integer (if it is stored as a string)
df['Model Year'] = pd.to_numeric(df['Model Year'], errors='coerce')

# Filter the dataset to only include Model Year 2018
df_2015 = df.query("`Model Year` == 2015")

# Group the filtered dataset by 'Make' and 'Fuel' columns and calculate the sum of 'Vehicles' in each group
vehicles_by_Fuel_Duty = df_2015.groupby(['Make', 'Fuel'])['Vehicles'].sum().sort_values(ascending=False)

# Print the results
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(vehicles_by_Fuel_Duty)

# Calculate the total number of vehicles in the filtered DataFrame for Model Year 2018
total_vehicles_2015 = df_2015['Vehicles'].sum()
print("Total number of vehicles in 2015:", total_vehicles_2015)
# Out:
# Make           Fuel
# TOYOTA         Gasoline                    59938
# HONDA          Gasoline                    52163
# NISSAN         Gasoline                    36640
# OTHER/UNK      Gasoline                    24479
# TOYOTA         Hybrid Gasoline             20767
# CHEVROLET      Gasoline                    17792
# FORD           Gasoline                    16256
# KIA            Gasoline                    14185
# BMW            Gasoline                    13766
# LEXUS          Gasoline                    13602
# MERCEDES-BENZ  Gasoline                    12093
# JEEP           Gasoline                    11245
# HYUNDAI        Gasoline                    10437
# OTHER/UNK      Diesel and Diesel Hybrid     9792
# SUBARU         Gasoline                     8245
# MAZDA          Gasoline                     7031
# OTHER/UNK      Flex-Fuel                    6820
# VOLKSWAGEN     Gasoline                     6732
# DODGE          Gasoline                     5455
# AUDI           Gasoline                     5223
# CHEVROLET      Flex-Fuel                    4555
# OTHER/UNK      Hybrid Gasoline              4318
# FORD           Flex-Fuel                    4280
# INFINITI       Gasoline                     3821
# ACURA          Gasoline                     3528
# OTHER/UNK      Plug-in Hybrid               3445
# FREIGHTLINER   Diesel and Diesel Hybrid     3128
# LEXUS          Hybrid Gasoline              3121
# GMC            Gasoline                     3051
# MINI           Gasoline                     2310
# OTHER/UNK      Battery Electric             2295
# SCION          Gasoline                     2292
# CHRYSLER       Gasoline                     2127
# MITSUBISHI     Gasoline                     1187
# CADILLAC       Gasoline                     1097
# PORSCHE        Gasoline                      953
# RAM            Gasoline                      831
# TESLA          Battery Electric              772
# FIAT           Gasoline                      552
# INTERNATIONAL  Diesel and Diesel Hybrid      508
# FORD           Diesel and Diesel Hybrid      470
# VOLVO          Gasoline                      448
# NEW FLYER      Natural Gas                   403
# BUICK          Gasoline                      303
# PETERBILT      Diesel and Diesel Hybrid      285
# DODGE          Flex-Fuel                     279
# KENWORTH       Diesel and Diesel Hybrid      252
# GMC            Flex-Fuel                     247
# OTHER/UNK      Natural Gas                   230
#                Unk                           200
# LAND ROVER     Gasoline                      195
# FORD           Hybrid Gasoline               191
# RAM            Diesel and Diesel Hybrid      188
# VOLKSWAGEN     Diesel and Diesel Hybrid      178
# HINO           Diesel and Diesel Hybrid      156
# HONDA          Hybrid Gasoline               148
# VOLVO          Diesel and Diesel Hybrid      145
# TOYOTA         Plug-in Hybrid                143
# Unk            Unk                           134
# FORD           Plug-in Hybrid                118
# KIA            Hybrid Gasoline                96
# ISUZU          Diesel and Diesel Hybrid       93
# FREIGHTLINER   Natural Gas                    74
# GILLIG         Diesel and Diesel Hybrid       69
# CHEVROLET      Plug-in Hybrid                 56
# LINCOLN        Gasoline                       49
# LAND ROVER     Flex-Fuel                      48
# FREIGHTLINER   Other                          44
# BLUE BIRD      Natural Gas                    42
# RAM            Flex-Fuel                      37
# AUTOCAR        Natural Gas                    36
# MERCEDES-BENZ  Diesel and Diesel Hybrid       27
# NISSAN         Battery Electric               23
# BENTLEY        Gasoline                       18
# THOMAS BUS     Natural Gas                    17
# HONDA          Natural Gas                    16
# BLUE BIRD      Other                          15
# CHEVROLET      Diesel and Diesel Hybrid       13
# FERRARI        Gasoline                       12
# ROLLS-ROYCE    Gasoline                       12
# GMC            Diesel and Diesel Hybrid       11
# OTHER/UNK      Other                          10
#                Hydrogen Fuel Cell              1
# Name: Vehicles, dtype: int64
# Total number of vehicles in 2015: 406364

# %%
# Convert the Series to a DataFrame
vehicles_by_Fuel_Duty_df = vehicles_by_Fuel_Duty.reset_index()

# Save the results as an Excel file
vehicles_by_Fuel_Duty_df.to_excel('vehicles_by_make_fuel_2015_zip.xlsx', index=False)

# Save the results as an CSV file
#vehicles_by_Fuel_Duty_df.to_csv('vehicles_by_make_fuel_2018_zip.csv', index=False)
