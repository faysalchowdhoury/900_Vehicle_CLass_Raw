# %%
import pandas as pd

df=pd.read_excel('filtered_data_los angles _zip.xlsx')


# Convert 'Model Year' column to integer (if it is stored as a string)
df['Model Year'] = pd.to_numeric(df['Model Year'], errors='coerce')

# Filter the dataset to only include Model Year 2018
df_2020 = df.query("`Model Year` == 2020")

# Group the filtered dataset by 'Make' and 'Fuel' columns and calculate the sum of 'Vehicles' in each group
vehicles_by_Fuel_Duty = df_2020.groupby(['Make', 'Fuel'])['Vehicles'].sum().sort_values(ascending=False)

# Print the results
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(vehicles_by_Fuel_Duty)

# Calculate the total number of vehicles in the filtered DataFrame for Model Year 2018
total_vehicles_2020 = df_2020['Vehicles'].sum()
print("Total number of vehicles in 2020:", total_vehicles_2020)
# Out:
# Make           Fuel
# TOYOTA         Gasoline                    53760
# HONDA          Gasoline                    44822
# OTHER/UNK      Gasoline                    23015
# CHEVROLET      Gasoline                    20163
# MERCEDES-BENZ  Gasoline                    19413
# NISSAN         Gasoline                    18501
# FORD           Gasoline                    17677
# BMW            Gasoline                    17383
# TESLA          Battery Electric            15244
# KIA            Gasoline                    14898
# HYUNDAI        Gasoline                    12391
# LEXUS          Gasoline                    12366
# JEEP           Gasoline                    11779
# SUBARU         Gasoline                    11760
# TOYOTA         Hybrid Gasoline             11242
# MAZDA          Gasoline                     7673
# VOLKSWAGEN     Gasoline                     7460
# OTHER/UNK      Diesel and Diesel Hybrid     6841
# LAND ROVER     Gasoline                     5433
# AUDI           Gasoline                     5313
# OTHER/UNK      Plug-in Hybrid               5083
# DODGE          Gasoline                     4552
# OTHER/UNK      Hybrid Gasoline              4452
# ACURA          Gasoline                     3809
# LEXUS          Hybrid Gasoline              3704
# INFINITI       Gasoline                     3256
# OTHER/UNK      Battery Electric             3238
#                Flex-Fuel                    3063
# PORSCHE        Gasoline                     3013
# HONDA          Hybrid Gasoline              2607
# FORD           Flex-Fuel                    2605
# VOLVO          Gasoline                     2352
# RAM            Gasoline                     2205
# GMC            Gasoline                     2197
# CADILLAC       Gasoline                     1964
# TOYOTA         Plug-in Hybrid               1564
# FORD           Hybrid Gasoline              1553
# CHEVROLET      Battery Electric             1290
# FREIGHTLINER   Diesel and Diesel Hybrid     1004
# ALFA ROMEO     Gasoline                      902
# MINI           Gasoline                      897
# MITSUBISHI     Gasoline                      850
# LINCOLN        Gasoline                      620
# INTERNATIONAL  Diesel and Diesel Hybrid      524
# JAGUAR         Gasoline                      440
# CHEVROLET      Flex-Fuel                     298
# CHRYSLER       Gasoline                      275
# PETERBILT      Diesel and Diesel Hybrid      274
# RAM            Diesel and Diesel Hybrid      270
# KIA            Hybrid Gasoline               266
# OTHER/UNK      Hydrogen Fuel Cell            263
# CHEVROLET      Diesel and Diesel Hybrid      259
# FREIGHTLINER   Gasoline                      252
# FORD           Diesel and Diesel Hybrid      237
# HINO           Diesel and Diesel Hybrid      236
# KENWORTH       Diesel and Diesel Hybrid      225
# BUICK          Gasoline                      212
# OTHER/UNK      Natural Gas                   194
# HONDA          Plug-in Hybrid                187
# BMW            Plug-in Hybrid                179
# PETERBILT      Natural Gas                   176
# OTHER/UNK      Unk                           162
# VOLVO          Diesel and Diesel Hybrid      152
# MERCEDES-BENZ  Diesel and Diesel Hybrid      133
# HYUNDAI        Hybrid Gasoline               126
# PORSCHE        Battery Electric              126
# ISUZU          Diesel and Diesel Hybrid      124
# BMW            Battery Electric              104
# NEW FLYER      Natural Gas                    94
# FREIGHTLINER   Natural Gas                    91
# EL DORADO      Natural Gas                    85
# AUTOCAR        Natural Gas                    67
# BENTLEY        Gasoline                       58
# MITSUBISHI     Plug-in Hybrid                 49
# KENWORTH       Natural Gas                    48
# Unk            Unk                            45
# AUDI           Plug-in Hybrid                 44
# KIA            Battery Electric               34
# MACK           Natural Gas                    34
# HYUNDAI        Battery Electric               34
# GMC            Diesel and Diesel Hybrid       27
# PROTERRA       Battery Electric               25
# FORD           Plug-in Hybrid                 24
# DODGE          Flex-Fuel                      23
# VOLVO          Natural Gas                    20
# NEW FLYER      Battery Electric               20
# OTHER/UNK      Other                          18
# THOMAS BUS     Natural Gas                    15
# MACK           Diesel and Diesel Hybrid       15
# ASTON MARTIN   Gasoline                       15
# ROLLS-ROYCE    Gasoline                       14
# KIA            Plug-in Hybrid                 14
# PORSCHE        Plug-in Hybrid                 13
# LAMBORGHINI    Gasoline                       13
# ARBOC          Natural Gas                    13
# KOVATCH        Diesel and Diesel Hybrid       12
# ISUZU          Gasoline                       12
# PIERCE         Diesel and Diesel Hybrid       11
# BLUE BIRD      Other                          11
# Name: Vehicles, dtype: int64
# Total number of vehicles in 2020: 400606

# %%
# Convert the Series to a DataFrame
vehicles_by_Fuel_Duty_df = vehicles_by_Fuel_Duty.reset_index()

# Save the results as an Excel file
vehicles_by_Fuel_Duty_df.to_excel('vehicles_by_make_fuel_2020_zip.xlsx', index=False)

# Save the results as an CSV file
#vehicles_by_Fuel_Duty_df.to_csv('vehicles_by_make_fuel_2018_zip.csv', index=False)
